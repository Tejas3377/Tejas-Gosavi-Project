# %%
# Cell 1: Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# update this path if different
dataset_path = "/content/drive/MyDrive/Plant_Disease_Dataset (1)"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 2: imports
import os
import pathlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TF version:", tf.__version__)
# Out:
# TF version: 2.19.0

# %%
# Cell 3: unzip (only if you uploaded a zip)
zip_path = "/content/drive/MyDrive/dataset.zip"  # change if needed
target_dir = "/content/drive/MyDrive/Plant_Disease_Dataset (1)"

if os.path.exists(zip_path):
    # !unzip -qq "{zip_path}" -d "{target_dir}"
    print("unzipped to", target_dir)
else:
    print("zip not found; skipping.")
# Out:
# zip not found; skipping.

# %%
# Cell 4: inspect
data_dir = pathlib.Path(dataset_path)
def count_images(exts=('*.jpg','*.jpeg','*.png')):
    counts = {}
    for sub in [p for p in data_dir.iterdir() if p.is_dir()]:
        c = 0
        for e in exts:
            c += len(list(sub.glob(e)))
        counts[sub.name] = c
    return counts

print("Dataset folder exists:", data_dir.exists())
print("Classes and counts:", count_images())
# Out:
# Dataset folder exists: True
# Classes and counts: {'test': 0, 'valid': 0, 'train': 0}

# %%
# Cell 5: create datasets
IMAGE_SIZE = (224, 224)       # change to 240/260 for EfficientNet variants
BATCH_SIZE = 32
SEED = 123

train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    labels='inferred',
    label_mode='categorical',    # use 'int' for sparse
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    labels='inferred',
    label_mode='categorical',
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)
# Out:
# Found 30 files belonging to 3 classes.
# Using 24 files for training.
# Found 30 files belonging to 3 classes.
# Using 6 files for validation.
# Classes: ['test', 'train', 'valid']

# %%
# Cell 6: optimise pipeline
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Data augmentation (in-model)
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.08),
])

# %%
# Cell 7: mixed precision (optional)
from tensorflow.keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
print("Compute dtype:", policy.compute_dtype, "Variable dtype:", policy.variable_dtype)
# Out:
# Compute dtype: float16 Variable dtype: float32

# %%
# Cell 8: model
base_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
)
base_model.trainable = False  # freeze for initial training

inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
# if mixed precision is on, set dtype float32 on final layer to avoid numeric issues
outputs = layers.Dense(num_classes, activation='softmax', dtype='float32')(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │         3,843 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,053,414 (15.46 MB)
#  Trainable params: 3,843 (15.01 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
# Cell 9: compile & callbacks
model_dir = "/content/drive/MyDrive/plant_disease_models"
os.makedirs(model_dir, exist_ok=True)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks = [
    keras.callbacks.ModelCheckpoint(os.path.join(model_dir, "best.h5"), save_best_only=True),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
]

# %%
# Cell 10: initial training
initial_epochs = 8
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=initial_epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - accuracy: 0.3333 - loss: 1.2054
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 36s 36s/step - accuracy: 0.3333 - loss: 1.2054 - val_accuracy: 0.1667 - val_loss: 1.2331 - learning_rate: 0.0010
# Epoch 2/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.4583 - loss: 1.0678 - val_accuracy: 0.1667 - val_loss: 1.2579 - learning_rate: 0.0010
# Epoch 3/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.3333 - loss: 1.0708 - val_accuracy: 0.1667 - val_loss: 1.2759 - learning_rate: 0.0010
# Epoch 4/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 0.9799 - val_accuracy: 0.0000e+00 - val_loss: 1.2816 - learning_rate: 0.0010
# Epoch 5/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step - accuracy: 0.6250 - loss: 1.0061 - val_accuracy: 0.0000e+00 - val_loss: 1.2806 - learning_rate: 5.0000e-04
# Epoch 6/8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 1.0349 - val_accuracy: 0.0000e+00 - val_loss: 1.2801 - learning_rate: 5.0000e-04

# %%
# Cell 11: fine tuning
base_model.trainable = True

# Option: unfreeze only last N layers for stability
for layer in base_model.layers[:-30]:
    layer.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

fine_epochs = 10
total_epochs = initial_epochs + fine_epochs

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1 if hasattr(history,'epoch') else initial_epochs,
    callbacks=callbacks
)
# Out:
# Epoch 7/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 55s 55s/step - accuracy: 0.2917 - loss: 1.1083 - val_accuracy: 0.1667 - val_loss: 1.2338 - learning_rate: 1.0000e-05
# Epoch 8/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 36s 36s/step - accuracy: 0.4167 - loss: 1.0579 - val_accuracy: 0.1667 - val_loss: 1.2350 - learning_rate: 1.0000e-05
# Epoch 9/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 28s 28s/step - accuracy: 0.2917 - loss: 1.1226 - val_accuracy: 0.1667 - val_loss: 1.2362 - learning_rate: 1.0000e-05
# Epoch 10/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 28s 28s/step - accuracy: 0.2917 - loss: 1.0954 - val_accuracy: 0.1667 - val_loss: 1.2366 - learning_rate: 1.0000e-05
# Epoch 11/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 27s 27s/step - accuracy: 0.3333 - loss: 1.1903 - val_accuracy: 0.1667 - val_loss: 1.2382 - learning_rate: 5.0000e-06
# Epoch 12/18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - accuracy: 0.4583 - loss: 1.0538 - val_accuracy: 0.1667 - val_loss: 1.2387 - learning_rate: 5.0000e-06

# %%
# Cell 12: evaluate & reports
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# Gather truths and preds from validation set
y_true = np.concatenate([y.numpy() for x,y in val_ds], axis=0)
y_true_idx = np.argmax(y_true, axis=1)
y_pred_probs = model.predict(val_ds)
y_pred_idx = np.argmax(y_pred_probs, axis=1)

print(classification_report(y_true_idx, y_pred_idx, target_names=class_names))
cm = confusion_matrix(y_true_idx, y_pred_idx)
print("Confusion matrix:\n", cm)

# %%
# Cell 13: save
model_dir = "/content/drive/MyDrive/plant_disease_models"
os.makedirs(model_dir, exist_ok=True)

model.export(os.path.join(model_dir, "plant_classifier_saved_model"))  # SavedModel
model.save(os.path.join(model_dir, "plant_classifier.h5"))            # HDF5
print("Saved to", model_dir)
# Out:
# Saved artifact at '/content/drive/MyDrive/plant_disease_models/plant_classifier_saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_489')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   138296207104464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207104656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207104080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139600464: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float16, name=None)
#   138296139601424: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float16, name=None)
#   138296207106192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207105040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207106960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207107920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207108496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207104848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207108304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207108880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207109456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207108688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207109840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207107728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207109264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207109648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207108112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207109072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207107536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207111568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207112144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207111376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207111952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207112528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207110224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207106768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207114064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207112912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207105616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207113296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194122960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194122768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194123728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194124304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194125072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194123344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194125264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194123536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194125648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194124880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194127184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194128144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194127952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194126800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194129872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194123920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194129680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194130256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194130832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194130064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194130640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194132176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194132752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194131408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194133520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194133712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194133136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194132368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194134096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194134672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194133328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194132944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194134480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194135056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194135632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194134864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194133904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194135440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194135824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194134288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194135248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194137360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194132560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194137168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194128720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194137744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194137552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194137936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296194136400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141693200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141694544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141694352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141693776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141693392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141693584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141695120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141693968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141695888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141696080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141695504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141694736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141696464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141697040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141695696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141695312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141696848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141697424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141697232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141696272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141697808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141696656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141697616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141699728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141699344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141699536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141699152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141700688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141701264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141701840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141701072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141700112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141701648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141700496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141701456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141703568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141698768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141703376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141703952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141704528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141703760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141703184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141704336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141704912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141705488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141704720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141705872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141705296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141705680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141704144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141706448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141705104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141706832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141706064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141708368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141708176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141708560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141706256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141708944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141707600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141706640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141702416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141708752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296141709136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140672528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140673104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140673872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140674064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140673488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140672720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140674448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140675024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140673680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140673296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140674832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140675408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140675984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140675216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140676368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140674256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140674640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140672912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140676752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140676944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140675600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140676560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140676176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296140665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139595856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139596048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139596624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139598544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139598928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139598352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139598736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139599504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139598160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139600272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139597008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139599696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139600080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139600656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296139601232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207106384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138296207107344: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved to /content/drive/MyDrive/plant_disease_models

# %%
# Cell 14: inference example
from tensorflow.keras.preprocessing import image
import numpy as np

def predict_image(img_path, model, image_size=IMAGE_SIZE):
    img = image.load_img(img_path, target_size=image_size)
    arr = image.img_to_array(img)
    arr = np.expand_dims(arr, 0)
    arr = tf.keras.applications.efficientnet.preprocess_input(arr)
    preds = model.predict(arr)
    idx = np.argmax(preds[0])
    return class_names[idx], float(np.max(preds[0]))

img_path = "/content/drive/MyDrive/Plant_Disease_Dataset (1)/test/AppleCedarRust1.JPG"  # change
print(predict_image(img_path, model))

# %%
# Cell 5: Predict & visualize single image (change image_rel_path as required)
image_rel_path = os.path.join('test','AppleCedarRust1.JPG')  # relative to dataset_path
image_path = os.path.join(dataset_path, image_rel_path)

# 1) Display
img_bgr = cv2.imread(image_path)
if img_bgr is None:
    raise FileNotFoundError(f"Image not found: {image_path}")
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5,5))
plt.imshow(img_rgb)
plt.title("Test Image")
plt.axis('off')
plt.show()

# 2) Preprocess & predict
img = tf.keras.preprocessing.image.load_img(image_path, target_size=IMAGE_SIZE)
arr = tf.keras.preprocessing.image.img_to_array(img)
arr = np.expand_dims(arr, axis=0)  # shape (1, H, W, 3)
# Use the same preprocessing as the training model
arr = tf.keras.applications.efficientnet.preprocess_input(arr)


preds = model.predict(arr) # Use 'model' defined in cell 'hG5u4gwNMK3F'
pred_idx = int(np.argmax(preds, axis=1)[0])
pred_conf = float(np.max(preds))
pred_label = class_names[pred_idx] if class_names else str(pred_idx)

print(f"Predicted: {pred_label}   Confidence: {pred_conf:.4f}")

# %%
# Cell 6: Batch predict a folder
test_folder = os.path.join(dataset_path, 'test')  # change to your test folder with images
out_csv = os.path.join(dataset_path, 'predictions.csv') # Changed filename for clarity

# get image file list by walking through subdirectories
exts = ('.jpg', '.jpeg', '.png', '.bmp')
img_files = []
for root, _, files in os.walk(test_folder):
    for f in files:
        if f.lower().endswith(exts):
            img_files.append(os.path.join(root, f))

img_files = sorted(img_files)
print("Found", len(img_files), "images in", test_folder)

results = []
batch_images = []
batch_files = []

# Import tqdm if not already imported
from tqdm import tqdm

for i, fpath in enumerate(tqdm(img_files, desc="Predicting")):
    img = tf.keras.preprocessing.image.load_img(fpath, target_size=IMAGE_SIZE)
    arr = tf.keras.preprocessing.image.img_to_array(img)
    batch_images.append(arr)
    batch_files.append(fpath)
    # predict in batches
    if len(batch_images) == BATCH_SIZE or i == len(img_files)-1:
        batch_np = np.stack(batch_images, axis=0) # Removed astype(np.float32) as preprocess_input handles dtype
        # Use the same preprocessing as the training model
        batch_np = tf.keras.applications.efficientnet.preprocess_input(batch_np)
        preds = model.predict(batch_np) # Use 'model' defined in cell 'hG5u4gwNMK3F'
        pred_idxs = np.argmax(preds, axis=1)
        pred_confs = np.max(preds, axis=1)
        for fname, pidx, pconf in zip(batch_files, pred_idxs, pred_confs):
            # Ensure class_names is available from the dataset creation step
            pred_label = class_names[int(pidx)] if 'class_names' in locals() and class_names else str(int(pidx))
            results.append({
                'filename': os.path.relpath(fname, dataset_path),
                'pred_index': int(pidx),
                'pred_label': pred_label,
                'confidence': float(pconf)
            })
        batch_images = []
        batch_files = []

# Save to CSV
import pandas as pd # Import pandas if not already imported
df = pd.DataFrame(results)
df.to_csv(out_csv, index=False)
print("Saved predictions to:", out_csv)
display(df.head(10))
# Out:
# Found 10 images in /content/drive/MyDrive/Plant_Disease_Dataset (1)/test
# Predicting:   0%|          | 0/10 [00:00<?, ?it/s]WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dc78b8e1b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# Predicting: 100%|██████████| 10/10 [00:08<00:00,  1.14it/s]
# Saved predictions to: /content/drive/MyDrive/Plant_Disease_Dataset (1)/predictions.csv
#                    filename  pred_index pred_label  confidence
# 0  test/AppleCedarRust1.JPG           1      train    0.434825
# 1  test/AppleCedarRust2.JPG           2      valid    0.416349
# 2  test/AppleCedarRust3.JPG           2      valid    0.373779
# 3  test/AppleCedarRust4.JPG           2      valid    0.398810
# 4       test/AppleScab1.JPG           2      valid    0.504739
# 5       test/AppleScab2.JPG           2      valid    0.460810
# 6       test/AppleScab3.JPG           1      train    0.481478
# 7  test/CornCommonRust1.JPG           0       test    0.419148
# 8  test/CornCommonRust2.JPG           2      valid    0.460597
# 9  test/CornCommonRust3.JPG           2      valid    0.407563
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['pred_index'].plot(kind='hist', bins=20, title='pred_index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['confidence'].plot(kind='hist', bins=20, title='confidence')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_18.groupby('pred_label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='index', y='pred_index', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='pred_index', y='confidence', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['pred_index']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_21.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('pred_label')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='pred_label', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('pred_index')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['confidence']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('pred_label')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='pred_label', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('confidence')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('pred_label')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='pred_label', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['pred_index'].plot(kind='line', figsize=(8, 4), title='pred_index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['confidence'].plot(kind='line', figsize=(8, 4), title='confidence')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['pred_label'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='index', y='pred_label', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_28['pred_label'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_28, x='pred_index', y='pred_label', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_29['pred_label'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_29, x='confidence', y='pred_label', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
